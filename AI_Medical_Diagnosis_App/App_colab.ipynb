# %%
# !git clone https://github.com/Shubham2376G/Seed_Hackathon.git
# Out:
# Cloning into 'Seed_Hackathon'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 58 (delta 9), reused 58 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 26.54 MiB | 21.08 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd Seed_Hackathon
# Out:
# /content/Seed_Hackathon

# %%
pip install streamlit
npm install localtunnel
pip install pymupdf
pip install fillpdf
pip install aisuite
pip install pymupdf4llm
pip install ag2
pip install PyPDF2 reportlab
pip install pdfrw

# %%
# !pip install streamlit
# !npm install localtunnel
# !pip install pymupdf
# !pip install fillpdf
# !pip install aisuite
# !pip install pymupdf4llm
# !pip install ag2[ollama]
# !pip install PyPDF2 reportlab
# !pip install pdfrw
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (1.40.2)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# ⠙⠹⠸⠼⠴⠦⠧
# up to date, audited 23 packages in 895ms
# ⠧
# ⠧3 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧
# 2 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠧Requirement already satisfied: pymupdf in /usr/local/lib/python3.10/dist-packages (1.24.14)
# Requirement already satisfied: fillpdf in /usr/local/lib/python3.10/dist-packages (0.7.3)
# Requirement already satisfied: pdfrw2 in /usr/local/lib/python3.10/dist-packages (from fillpdf) (0.5.0)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (from fillpdf) (1.17.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fillpdf) (11.0.0)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.10/dist-packages (from fillpdf) (1.24.14)
# Requirement already satisfied: aisuite in /usr/local/lib/python3.10/dist-packages (0.1.6)
# Requirement already satisfied: pymupdf4llm in /usr/local/lib/python3.10/dist-packages (0.0.17)
# Requirement already satisfied: pymupdf>=1.24.10 in /usr/local/lib/python3.10/dist-packages (from pymupdf4llm) (1.24.14)
# Requirement already satisfied: ag2[ollama] in /usr/local/lib/python3.10/dist-packages (0.4)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (5.6.3)
# Requirement already satisfied: docker in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (7.1.0)
# Requirement already satisfied: flaml in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (2.3.2)
# Requirement already satisfied: openai>=1.3 in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (1.54.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (24.2)
# Requirement already satisfied: pydantic!=2.6.0,<3,>=1.10 in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (2.9.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (1.0.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (2.5.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (0.8.0)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (1.26.4)
# Requirement already satisfied: fix-busted-json>=0.0.18 in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (0.0.18)
# Requirement already satisfied: ollama>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from ag2[ollama]) (0.4.1)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from ollama>=0.3.3->ag2[ollama]) (0.27.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3->ag2[ollama]) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3->ag2[ollama]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3->ag2[ollama]) (0.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.3->ag2[ollama]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3->ag2[ollama]) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3->ag2[ollama]) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.6.0,<3,>=1.10->ag2[ollama]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.6.0,<3,>=1.10->ag2[ollama]) (2.23.4)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from docker->ag2[ollama]) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker->ag2[ollama]) (2.2.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->ag2[ollama]) (2024.9.11)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.3->ag2[ollama]) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.3->ag2[ollama]) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama>=0.3.3->ag2[ollama]) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama>=0.3.3->ag2[ollama]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama>=0.3.3->ag2[ollama]) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->docker->ag2[ollama]) (3.4.0)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: reportlab in /usr/local/lib/python3.10/dist-packages (4.2.5)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from reportlab) (11.0.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from reportlab) (5.2.0)
# Collecting pdfrw
#   Downloading pdfrw-0.4-py2.py3-none-any.whl.metadata (32 kB)
# Downloading pdfrw-0.4-py2.py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: pdfrw
# Successfully installed pdfrw-0.4

# %%
# !sudo apt-get install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids
# The following NEW packages will be installed:
#   libpci3 pci.ids pciutils
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 343 kB of archives.
# After this operation, 1,581 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 pci.ids all 0.0~2022.01.22-1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Fetched 343 kB in 1s (473 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package pci.ids.
# (Reading database ... 123630 files and directories currently installed.)
# Preparing to unpack .../pci.ids_0.0~2022.01.22-1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../pciutils_1%3a3.7.0-6_amd64.deb ...
# Unpacking pciutils (1:3.7.0-6) ...
# Setting up pci.ids (0.0~2022.01.22-1) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up pciutils (1:3.7.0-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# # !sudo apt-get install -y pciutils
# # !curl -fsSL https://ollama.com/install.sh | sh

# import os
# import threading
# import subprocess
# import requests
# import json

# def ollama():
#   os.environ["OLLAMA_HOST"]= "0.0.0.0:11434"
#   os.environ["OLLAMA_ORIGINS"]= "*"
#   subprocess.Popen(["ollama","serve"])

# ollama_thread=threading.Thread(target=ollama)
# ollama_thread.start()

# %%
# !ollama serve > server.log 2>&1 &

# %%
# !ollama pull meditron
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling ca7d20b78b4a...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   0% ▕▏ 1.9 MB/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   0% ▕▏ 7.9 MB/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   1% ▕▏  34 MB/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   2% ▕▏  65 MB/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   2% ▕▏  87 MB/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   3% ▕▏ 121 MB/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   4% ▕▏ 157 MB/3.8 GB                  pulling manifest
# pulling ca7d20b78b4a...   5% ▕▏ 201 MB/3.8 GB  191 MB/s     18spulling manifest
# pulling ca7d20b78b4a...   6% ▕▏ 232 MB/3.8 GB  191 MB/s     18spulling manifest
# pulling ca7d20b78b4a...   7% ▕▏ 274 MB/3.8 GB  191 MB/s     18spulling manifest
# pulling ca7d20b78b4a...   7% ▕▏ 283 MB/3.8 GB  191 MB/s     18spulling manifest
# pulling ca7d20b78b4a...   9% ▕▏ 329 MB/3.8 GB  191 MB/s     18spulling manifest
# pulling ca7d20b78b4a...  10% ▕▏ 382 MB/3.8 GB  191 MB/s     17spulling manifest
# pulling ca7d20b78b4a...  10% ▕▏ 396 MB/3.8 GB  191 MB/s     17spulling manifest
# pulling ca7d20b78b4a...  11% ▕▏ 434 MB/3.8 GB  191 MB/s     17spulling manifest
# pulling ca7d20b78b4a...  13% ▕▏ 482 MB/3.8 GB  191 MB/s     17spulling manifest
# pulling ca7d20b78b4a...  13% ▕▏ 503 MB/3.8 GB  191 MB/s     17spulling manifest
# pulling ca7d20b78b4a...  14% ▕▏ 538 MB/3.8 GB  269 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  15% ▕▏ 557 MB/3.8 GB  269 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  15% ▕▏ 576 MB/3.8 GB  269 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  16% ▕▏ 597 MB/3.8 GB  269 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  16% ▕▏ 620 MB/3.8 GB  269 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  17% ▕▏ 644 MB/3.8 GB  269 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  18% ▕▏ 686 MB/3.8 GB  269 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  19% ▕▏ 721 MB/3.8 GB  269 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  19% ▕▏ 742 MB/3.8 GB  269 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 750 MB/3.8 GB  269 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 752 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 752 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 752 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 752 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 753 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 753 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 753 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 754 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 754 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 754 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 754 MB/3.8 GB  250 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 755 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 755 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 755 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 756 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 756 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 756 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 756 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 757 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  20% ▕▏ 772 MB/3.8 GB  188 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  22% ▕▏ 860 MB/3.8 GB  188 MB/s     15spulling manifest
# pulling ca7d20b78b4a...  23% ▕▏ 880 MB/3.8 GB  176 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  25% ▕▏ 940 MB/3.8 GB  176 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  25% ▕▏ 960 MB/3.8 GB  176 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  26% ▕▏ 999 MB/3.8 GB  176 MB/s     16spulling manifest
# pulling ca7d20b78b4a...  27% ▕▏ 1.0 GB/3.8 GB  176 MB/s     15spulling manifest
# pulling ca7d20b78b4a...  27% ▕▏ 1.1 GB/3.8 GB  176 MB/s     15spulling manifest
# pulling ca7d20b78b4a...  29% ▕▏ 1.1 GB/3.8 GB  176 MB/s     15spulling manifest
# pulling ca7d20b78b4a...  29% ▕▏ 1.1 GB/3.8 GB  176 MB/s     15spulling manifest
# pulling ca7d20b78b4a...  30% ▕▏ 1.1 GB/3.8 GB  176 MB/s     15spulling manifest
# pulling ca7d20b78b4a...  32% ▕▏ 1.2 GB/3.8 GB  176 MB/s     14spulling manifest
# pulling ca7d20b78b4a...  32% ▕▏ 1.2 GB/3.8 GB  202 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  33% ▕▏ 1.2 GB/3.8 GB  202 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  34% ▕▏ 1.3 GB/3.8 GB  202 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  34% ▕▏ 1.3 GB/3.8 GB  202 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  35% ▕▏ 1.3 GB/3.8 GB  202 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  36% ▕▏ 1.4 GB/3.8 GB  202 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  36% ▕▏ 1.4 GB/3.8 GB  202 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  37% ▕▏ 1.4 GB/3.8 GB  202 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  202 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  202 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  205 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.4 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  38% ▕▏ 1.5 GB/3.8 GB  180 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  39% ▕▏ 1.5 GB/3.8 GB  180 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  40% ▕▏ 1.5 GB/3.8 GB  168 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  41% ▕▏ 1.6 GB/3.8 GB  168 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  41% ▕▏ 1.6 GB/3.8 GB  168 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  42% ▕▏ 1.6 GB/3.8 GB  168 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  42% ▕▏ 1.6 GB/3.8 GB  168 MB/s     13spulling manifest
# pulling ca7d20b78b4a...  43% ▕▏ 1.6 GB/3.8 GB  168 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  43% ▕▏ 1.7 GB/3.8 GB  168 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  44% ▕▏ 1.7 GB/3.8 GB  168 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  45% ▕▏ 1.7 GB/3.8 GB  168 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  45% ▕▏ 1.7 GB/3.8 GB  168 MB/s     12spulling manifest
# pulling ca7d20b78b4a...  46% ▕▏ 1.8 GB/3.8 GB  173 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  47% ▕▏ 1.8 GB/3.8 GB  173 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  47% ▕▏ 1.8 GB/3.8 GB  173 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  48% ▕▏ 1.8 GB/3.8 GB  173 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  48% ▕▏ 1.9 GB/3.8 GB  173 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  49% ▕▏ 1.9 GB/3.8 GB  173 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  50% ▕▏ 1.9 GB/3.8 GB  173 MB/s     11spulling manifest
# pulling ca7d20b78b4a...  50% ▕▏ 1.9 GB/3.8 GB  173 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  51% ▕▏ 2.0 GB/3.8 GB  173 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  52% ▕▏ 2.0 GB/3.8 GB  173 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  53% ▕▏ 2.0 GB/3.8 GB  163 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  53% ▕▏ 2.0 GB/3.8 GB  163 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  54% ▕▏ 2.1 GB/3.8 GB  163 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  54% ▕▏ 2.1 GB/3.8 GB  163 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  55% ▕▏ 2.1 GB/3.8 GB  163 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  56% ▕▏ 2.1 GB/3.8 GB  163 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  56% ▕▏ 2.2 GB/3.8 GB  163 MB/s     10spulling manifest
# pulling ca7d20b78b4a...  58% ▕▏ 2.2 GB/3.8 GB  163 MB/s      9spulling manifest
# pulling ca7d20b78b4a...  58% ▕▏ 2.2 GB/3.8 GB  163 MB/s      9spulling manifest
# pulling ca7d20b78b4a...  59% ▕▏ 2.3 GB/3.8 GB  163 MB/s      9spulling manifest
# pulling ca7d20b78b4a...  60% ▕▏ 2.3 GB/3.8 GB  172 MB/s      8spulling manifest
# pulling ca7d20b78b4a...  61% ▕▏ 2.3 GB/3.8 GB  172 MB/s      8spulling manifest
# pulling ca7d20b78b4a...  62% ▕▏ 2.4 GB/3.8 GB  172 MB/s      8spulling manifest
# pulling ca7d20b78b4a...  63% ▕▏ 2.4 GB/3.8 GB  172 MB/s      8spulling manifest
# pulling ca7d20b78b4a...  64% ▕▏ 2.4 GB/3.8 GB  172 MB/s      8spulling manifest
# pulling ca7d20b78b4a...  65% ▕▏ 2.5 GB/3.8 GB  172 MB/s      7spulling manifest
# pulling ca7d20b78b4a...  65% ▕▏ 2.5 GB/3.8 GB  172 MB/s      7spulling manifest
# pulling ca7d20b78b4a...  66% ▕▏ 2.5 GB/3.8 GB  172 MB/s      7spulling manifest
# pulling ca7d20b78b4a...  66% ▕▏ 2.5 GB/3.8 GB  172 MB/s      7spulling manifest
# pulling ca7d20b78b4a...  67% ▕▏ 2.6 GB/3.8 GB  172 MB/s      7spulling manifest
# pulling ca7d20b78b4a...  68% ▕▏ 2.6 GB/3.8 GB  205 MB/s      5spulling manifest
# pulling ca7d20b78b4a...  68% ▕▏ 2.6 GB/3.8 GB  205 MB/s      5spulling manifest
# pulling ca7d20b78b4a...  69% ▕▏ 2.6 GB/3.8 GB  205 MB/s      5spulling manifest
# pulling ca7d20b78b4a...  70% ▕▏ 2.7 GB/3.8 GB  205 MB/s      5spulling manifest
# pulling ca7d20b78b4a...  71% ▕▏ 2.7 GB/3.8 GB  205 MB/s      5spulling manifest
# pulling ca7d20b78b4a...  71% ▕▏ 2.7 GB/3.8 GB  205 MB/s      5spulling manifest
# pulling ca7d20b78b4a...  72% ▕▏ 2.8 GB/3.8 GB  205 MB/s      5spulling manifest
# pulling ca7d20b78b4a...  73% ▕▏ 2.8 GB/3.8 GB  205 MB/s      5spulling manifest
# pulling ca7d20b78b4a...  73% ▕▏ 2.8 GB/3.8 GB  205 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  74% ▕▏ 2.8 GB/3.8 GB  205 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  75% ▕▏ 2.9 GB/3.8 GB  205 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  75% ▕▏ 2.9 GB/3.8 GB  220 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  76% ▕▏ 2.9 GB/3.8 GB  220 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  77% ▕▏ 2.9 GB/3.8 GB  220 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  77% ▕▏ 3.0 GB/3.8 GB  220 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  78% ▕▏ 3.0 GB/3.8 GB  220 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  78% ▕▏ 3.0 GB/3.8 GB  220 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  79% ▕▏ 3.0 GB/3.8 GB  220 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  80% ▕▏ 3.1 GB/3.8 GB  220 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  80% ▕▏ 3.1 GB/3.8 GB  220 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  220 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  207 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      4spulling manifest
# pulling ca7d20b78b4a...  81% ▕▏ 3.1 GB/3.8 GB  183 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  83% ▕▏ 3.2 GB/3.8 GB  194 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  84% ▕▏ 3.2 GB/3.8 GB  194 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  85% ▕▏ 3.2 GB/3.8 GB  194 MB/s      3spulling manifest
# pulling ca7d20b78b4a...  85% ▕▏ 3.3 GB/3.8 GB  194 MB/s      2spulling manifest
# pulling ca7d20b78b4a...  86% ▕▏ 3.3 GB/3.8 GB  194 MB/s      2spulling manifest
# pulling ca7d20b78b4a...  87% ▕▏ 3.3 GB/3.8 GB  194 MB/s      2spulling manifest
# pulling ca7d20b78b4a...  88% ▕▏ 3.4 GB/3.8 GB  194 MB/s      2spulling manifest
# pulling ca7d20b78b4a...  89% ▕▏ 3.4 GB/3.8 GB  194 MB/s      2spulling manifest
# pulling ca7d20b78b4a...  89% ▕▏ 3.4 GB/3.8 GB  194 MB/s      2spulling manifest
# pulling ca7d20b78b4a...  90% ▕▏ 3.5 GB/3.8 GB  194 MB/s      1spulling manifest
# pulling ca7d20b78b4a...  92% ▕▏ 3.5 GB/3.8 GB  220 MB/s      1spulling manifest
# pulling ca7d20b78b4a...  92% ▕▏ 3.5 GB/3.8 GB  220 MB/s      1spulling manifest
# pulling ca7d20b78b4a...  93% ▕▏ 3.6 GB/3.8 GB  220 MB/s      1spulling manifest
# pulling ca7d20b78b4a...  94% ▕▏ 3.6 GB/3.8 GB  220 MB/s      1spulling manifest
# pulling ca7d20b78b4a...  94% ▕▏ 3.6 GB/3.8 GB  220 MB/s      1spulling manifest
# pulling ca7d20b78b4a...  95% ▕▏ 3.6 GB/3.8 GB  220 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  95% ▕▏ 3.6 GB/3.8 GB  220 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  95% ▕▏ 3.6 GB/3.8 GB  220 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  95% ▕▏ 3.7 GB/3.8 GB  220 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  220 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  220 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  96% ▕▏ 3.7 GB/3.8 GB  212 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  186 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  97% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.7 GB/3.8 GB  157 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.7 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  98% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  127 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB  100 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a...  99% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   79 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   68 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   35 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   35 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   35 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   35 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   35 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB/3.8 GB   35 MB/s      0spulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552...   0% ▕▏    0 B/ 106 B                  pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552...   0% ▕▏    0 B/ 106 B                  pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9...   0% ▕▏    0 B/ 155 B                  pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276...   0% ▕▏    0 B/  74 B                  pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276...   0% ▕▏    0 B/  74 B                  pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226...   0% ▕▏    0 B/ 455 B                  pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226...   0% ▕▏    0 B/ 455 B                  pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226...   0% ▕▏    0 B/ 455 B                  pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B                         pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠋ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠙ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠹ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠸ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠼ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠴ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠦ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠧ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠇ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠏ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠋ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠙ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠹ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠸ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠼ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠴ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠦ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠧ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠇ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠏ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠋ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠙ pulling manifest
# ...
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠏ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠋ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠙ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠹ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠸ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠼ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠴ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠦ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠧ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠇ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠏ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠋ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠙ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠹ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠸ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠼ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠴ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠦ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠧ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠇ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠏ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠋ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠙ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠹ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠸ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠼ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠴ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠦ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠧ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠇ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠏ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠋ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠙ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠹ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠸ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠼ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠴ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠦ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠧ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠇ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠏ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠋ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest ⠙ pulling manifest
# pulling ca7d20b78b4a... 100% ▕▏ 3.8 GB
# pulling a47b02e00552... 100% ▕▏  106 B
# pulling e3d94d483bb9... 100% ▕▏  155 B
# pulling 6ee262b64276... 100% ▕▏   74 B
# pulling 25481b76a226... 100% ▕▏  455 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !ollama pull gemma:2b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling c1864a5eb193... 100% ▕▏ 1.7 GB
# pulling 097a36493f71... 100% ▕▏ 8.4 KB
# pulling 109037bec39c... 100% ▕▏  136 B
# pulling 22a838ceb7fb... 100% ▕▏   84 B
# pulling 887433b89a90... 100% ▕▏  483 B
# verifying sha256 digest
# writing manifest
# success

# %%
# %%writefile app5.py


import ast
import tempfile
import pymupdf4llm
import pymupdf
import datetime
from autogen import ConversableAgent
from Report_generator import *
from main_model import *
from overlay_cam import *


# gemma={
#     "config_list" : [
#     {
#         # Let's choose the Meta's Llama 3.1 model (model names must match Ollama exactly)
#         "model": "meditron",
#         # We specify the API Type as 'ollama' so it uses the Ollama client class
#         "api_type": "ollama",
#         "stream": False,
#         "client_host": "http://127.0.0.1:11434",
#     }
# ]
# }


##############################################################
# patient symptoms
# use directly will think layer if i want to extract symptoms or not

################################################################
#medical imaging


# xray_agent = ConversableAgent(
#     "blood_test",
#     system_message="You are a doctor, your work is to extract the results of the complete blood count test along with reference value, and also mention if its high or low, just print results nothing else",
#     llm_config=gemma,
#     code_execution_config=False,  # Turn off code execution, by default it is off.
#     function_map=None,  # No registered functions, by default it is None.
#     human_input_mode="NEVER",  # Never ask for human input.
# )

# cbc_report = cbc_agent.generate_reply(messages=[{"content": md_text, "role": "user"}])
# print(cbc_report)


##########################################################
# main model

# doctor_agent = ConversableAgent(
#     "Doctor",
#     system_message="You are a doctor, I have provided you patient history, his blood test result (if any) and x ray result (if any), using this information , identify which disease the patient might be suffering from, give response in following dictionary format {response: your response , logs: here you will give explaination of why you gave this result } ",
#     llm_config=gemma,
#     code_execution_config=False,  # Turn off code execution, by default it is off.
#     function_map=None,  # No registered functions, by default it is None.
#     human_input_mode="NEVER",  # Never ask for human input.
# )

# doctor_report = doctor_agent.generate_reply(messages=[{"content": md_text, "role": "user"}])
# print(doctor_report)


########################################################
# Blood test

# cbc_agent = ConversableAgent(
#     "blood_test",
#     system_message="You are a doctor, your work is to extract the results of the complete blood count test along with reference value, and also mention if its high or low, just print results nothing else",
#     llm_config=gemma,
#     code_execution_config=False,  # Turn off code execution, by default it is off.
#     function_map=None,  # No registered functions, by default it is None.
#     human_input_mode="NEVER",  # Never ask for human input.
# )

# cbc_report = cbc_agent.generate_reply(messages=[{"content": md_text, "role": "user"}])
# print(cbc_report)


import streamlit as st

# Initialize patient history in session state
if "patient_history" not in st.session_state:
    st.session_state.patient_history = {}

# Sidebar: Navigation
st.sidebar.title("Navigation")
page = st.sidebar.radio("Go to:", ["Form Page","Document Query", "History"])

# Main content
if page == "Form Page":
    # Form Page
    st.title("🩺 Patient Diagnosis Form")
    st.write("Please fill in the following details to help us better assess your condition.")

    # Patient Details Section
    st.header("1. Patient Details")
    col1, col2, col3 = st.columns(3)

    with col1:
        name = st.text_input("Name:", placeholder="Enter your full name")
    with col2:
        gender = st.selectbox("Gender:", ["Male", "Female", "Other", "Prefer not to say"])
    with col3:
        age = st.number_input("Age:", min_value=0, max_value=120, step=1, format="%d")

    # Symptoms Section
    st.header("2. Patient Symptoms")
    symptoms = st.text_area(
        "Describe your symptoms in detail:",
        placeholder="E.g., fever, cough, chest pain, etc."
    )

    # Upload Blood Test Report Section
    st.header("3. Upload Blood Test Report")
    blood_test = st.file_uploader(
        "Upload your blood test report (optional):",
        type=["pdf", "jpg", "png", "jpeg"],
        help="Supported formats: PDF, JPG, PNG, JPEG"
    )

    # Upload Imaging Section
    st.header("4. Upload Imaging Files")
    imaging_files = st.file_uploader(
        "Upload your imaging files (optional):",
        type=["pdf", "jpg", "png", "jpeg", "dcm"],
        help="Supported formats: PDF, JPG, PNG, JPEG"
    )

    model_category = st.selectbox(
        "Select inference model:",
        ["Gemma:2b", "Medllama2:7b", "Meditron:7b", "Mistral:7b", "GPT4"]
    )

    # Submission Button
    if st.button("Submit"):
        if not name:
            st.error("Please provide your name.")
        elif not age:
            st.error("Please provide your age.")
        elif not symptoms:
            st.error("Please describe your symptoms.")
        else:
            st.success("Form submitted successfully!")
            st.write("### Summary of Your Submission:")
            st.write(f"**Patient:** {name}, {gender}, {age} ")
            st.write(f"**Symptoms Described:** {symptoms}")
            st.write(f"**Model:** {model_category}")


            if blood_test:
                st.write("**Blood Test Report:** Uploaded")
                data = blood_test.getvalue()
                with tempfile.NamedTemporaryFile(delete=False, suffix=".pdf") as temp_file:
                  temp_file.write(data)
                  cbc_report = pymupdf4llm.to_markdown(temp_file.name)
                  # cbc_report = cbc_agent.generate_reply(messages=[{"content": cbc_report, "role": "user"}])

            else:
                st.write("**Blood Test Report:** Not provided")
                cbc_report="none"

            if imaging_files:
                st.write(f"**Imaging Files:** Uploaded:")

                data_xray = imaging_files.getvalue()
                with tempfile.NamedTemporaryFile(delete=False, suffix=".pdf") as temp_file_xray:
                    temp_file_xray.write(data_xray)
                    xray=xray_output()

            else:
                st.write("**Imaging Files:** Not provided")
                xray="none"

            doctor_report = main_inference(model_category,symptoms,cbc_report,xray)
            # doctor_report = doctor_agent.generate_reply(messages=[{"content": f"patient history are {gender} ,age {age} , {symptoms} , blood test report is {cbc_report} , and xray result {xray}, what disease the patient is suffering from ", "role": "user"}])
            # doctor_report=doctor_report
            st.write("### Diagnosis Report:")
            st.write(doctor_report)


            report_gen(name,age,gender,symptoms,doctor_report,str(datetime.datetime.now().date()),xray)

            file_path = f"Records/{name}_full.pdf"
            # file_path = f"{name}.pdf"

            with open(file_path, "rb") as file:
              file_data = file.read()

            # Add a download button
            st.download_button(
                label="Download AI Diagnosis PDF",
                data=file_data,
                file_name=f"{name}_diagnosis.pdf",
                mime="application/pdf"
            )


elif page == "Document Query":
    # Dynamic Page
    st.title("📑 Document Query")
    st.write("Query over you documents here")

    rag = st.file_uploader(
        "Upload your document here",
        type=["pdf", "jpg", "png", "jpeg"],
        help="Supported formats: PDF, JPG, PNG, JPEG")

    query = st.text_area(
        "Enter your query:",
        placeholder="E.g., what is the diagnosis test for"
    )


    if st.button("Submit"):
      if not rag:
        st.error("Please provide a document")
      else:
        st.success("submitted successfully! Querying... ")
        st.write("### Summary of Your Submission:")







elif page == "History":
    # Dynamic Page
    st.title("📊 Patient Statistics & Insights")
    st.write("This page dynamically displays aggregated patient data.")

    if st.session_state.patient_history:
        st.write("### Patient History Overview")
        for name, data in st.session_state.patient_history.items():
            st.write(f"**Name:** {name}")
            st.write(f"**Age:** {data['age']} | **Gender:** {data['gender']}")
            st.write(f"**Symptom Category:** {data['symptom_category']}")
            st.write("---")
    else:
        st.warning("No patient data available. Please add patients from the Form Page.")

# Footer
st.markdown("---")
# Out:
# Overwriting app5.py

# %%
# !streamlit run app5.py &>/content/logs.txt & npx localtunnel --port 8501 & curl https://loca.lt/mytunnelpassword
# Out:
# ⠙34.16.138.103your url is: https://floppy-webs-share.loca.lt

# %%
# !ollama serve > server.log 2>&1 &

# %%
# !ollama pull medllama2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling f050c123dbd6... 100% ▕▏ 3.8 GB
# pulling 4dec76bb1a47... 100% ▕▏   45 B
# pulling 0644cce03f93... 100% ▕▏   31 B
# pulling f3d56c5b85c0... 100% ▕▏  381 B
# verifying sha256 digest
# writing manifest
# success

# %%
import os

# Specify the folder name
folder_name = "outputs"

# Check if the folder already exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    print(f"Folder '{folder_name}' created successfully!")
else:
    print(f"Folder '{folder_name}' already exists.")
# Out:
# Folder 'outputs' created successfully!

# %%
from autogen import ConversableAgent
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
gemma={
    "config_list" : [
    {
        # Let's choose the Meta's Llama 3.1 model (model names must match Ollama exactly)
        "model": "meditron",
        # We specify the API Type as 'ollama' so it uses the Ollama client class
        "api_type": "ollama",
        "stream": False,
        "client_host": "http://127.0.0.1:11434",
    }
]
}


doctor_agent = ConversableAgent(
    "Doctor",
    system_message="You are a doctor, analysis the symptoms and tell which disease patient might be suffering from I have provided you patient history} ",
    llm_config=gemma,
    code_execution_config=False,  # Turn off code execution, by default it is off.
    function_map=None,  # No registered functions, by default it is None.
    human_input_mode="NEVER",  # Never ask for human input.
)



doctor_report = doctor_agent.generate_reply(messages=[{"content": f"patient history are male ,age 9 , hi my nine year old son had a cough and flu symptons three months ago and the chesty sounding cough and green phlegm still remains. it did seem to get better but never totally went and has now picked up again...he has only ever had antibiotics once in his live which suggests he his generally fitand well and active...never short of breath or weezy...so why would this be , blood test report is none , and xray result none, what disease the patient is suffering from ", "role": "user"}])
doctor_report
# Out:
# {'content': 'You are a doctor. You need to find out the disease he/she is suffering with by analysing his past history. What could be the disease?\n',
#  'refusal': None,
#  'role': 'assistant',
#  'audio': None,
#  'function_call': None,
#  'tool_calls': None}

# %%
import aisuite as ai


client = ai.Client()




messages = [
    {"role": "system", "content": "You are a doctor, and your role is to diagnose a patient based on the symptoms provided. I will describe the symptoms, and you need to tell me the potential disease the patient might be suffering from, with a clear and detailed answer and also tell why you think that the patient might be suffering from that. Do not provide any other information or dialogue besides the diagnosis. Provide the diagnosis in full immediately after receiving the symptoms."},
    {"role": "user", "content": "symptoms are fever, cough, skin rash, less hunger, what disease he is suffering from ?"},
]


response = client.chat.completions.create(
    model="ollama:medllama2",
    messages=messages,
    temperature=0.1
)
print(response.choices[0].message.content)
# Out:
# The patient's symptoms suggest a likely case of bacterial pneumonia, a serious infection that affects the lungs. Bacteria like Streptococcus pneumoniae can cause it and usually requires antibiotic treatment. The skin rash is an additional sign pointing to this condition. If you have any questions or concerns about this diagnosis, please feel free to ask. (Source: MedlinePlus)
